# %%
import pandas as pd

# %%
df = pd.read_csv("hotel_comments.csv")

# %%
df=df[:10000]
df
# Out:
#         num Hotel ID Reviewer ID Reviewer Name Nationality  \
# 0         1      1_1       1_1_1        MARIKO    Nhật Bản
# 1         2      1_1       1_1_2          Hong    Việt Nam
# 2         3      1_1       1_1_3          Guai    Việt Nam
# 3         4      1_1       1_1_4         Nghĩa    Việt Nam
# 4         5      1_1       1_1_5           Duc    Việt Nam
# ...     ...      ...         ...           ...         ...
# 9995   9996     1_24   1_24_1084            Ka    Malaysia
# 9996   9997     1_24   1_24_1085          John          Úc
# 9997   9998     1_24   1_24_1086         Leata          Úc
# 9998   9999     1_24   1_24_1087           van        Pháp
# 9999  10000     1_24   1_24_1088          Chen    Đài Loan
#
#               Group Name                                          Room Type  \
# 0                Cặp đôi             Phòng Deluxe 2 Giường đơn Nhìn ra Biển
# 1            Đi công tác             Phòng Deluxe 2 Giường đơn Nhìn ra Biển
# ...

# %%
df.to_csv("sample_hotel_comments.csv", index=False)
